# %%
import matplotlib.pyplot as plt
import pickle

# %%
with open('../pkl_file/true_data.pkl', 'rb') as f:
    profile_list = pickle.load(f)

# %%
for i in range(54):
    plt.plot(profile_list[i])
plt.show()
